# %% [markdown]
# <a href="https://colab.research.google.com/github/cuongvng/TF-Lite-Cpp-API-for-Android/blob/main/run_me.ipynb" target="_parent">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# !git clone https://github.com/tensorflow/tensorflow
# Out:
# Cloning into 'tensorflow'...
# remote: Enumerating objects: 1114991, done.
# remote: Total 1114991 (delta 0), reused 0 (delta 0), pack-reused 1114991
# Receiving objects: 100% (1114991/1114991), 655.09 MiB | 26.31 MiB/s, done.
# Resolving deltas: 100% (908922/908922), done.
# Checking out files: 100% (24546/24546), done.

# %%
# %cd tensorflow
# Out:
# /content/tensorflow

# %% [markdown]
# ### Install [bazel](https://docs.bazel.build/versions/4.0.0/install-ubuntu.html#install-on-ubuntu) to build tf lite library for C++

# %%
# !sudo apt install curl gnupg
# !curl -fsSL https://bazel.build/bazel-release.pub.gpg | gpg --dearmor > bazel.gpg
# !sudo mv bazel.gpg /etc/apt/trusted.gpg.d/
# !echo "deb [arch=amd64] https://storage.googleapis.com/bazel-apt stable jdk1.8" | sudo tee /etc/apt/sources.list.d/bazel.list
# !sudo apt update && sudo apt install bazel
# !sudo apt update && sudo apt full-upgrade
# !sudo apt install bazel-3.7.2
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following packages were automatically installed and are no longer required:
#   linux-headers-4.15.0-137 linux-headers-4.15.0-137-generic
# Use 'sudo apt autoremove' to remove them.
# Suggested packages:
#   bash-completion
# The following NEW packages will be installed:
#   bazel-3.7.2
# 0 upgraded, 1 newly installed, 0 to remove and 4 not upgraded.
# Need to get 44.0 MB of archives.
# After this operation, 0 B of additional disk space will be used.
# Get:1 https://storage.googleapis.com/bazel-apt stable/jdk1.8 amd64 bazel-3.7.2 amd64 3.7.2 [44.0 MB]
# Fetched 44.0 MB in 1s (37.0 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package bazel-3.7.2.
# (Reading database ... 190296 files and directories currently installed.)
# Preparing to unpack .../bazel-3.7.2_3.7.2_amd64.deb ...
# Unpacking bazel-3.7.2 (3.7.2) ...
# Setting up bazel-3.7.2 (3.7.2) ...

# %% [markdown]
# ### Build C++ API libraries

# %%
# For ARM 64 bit
# !bazel build -c opt //tensorflow/lite:libtensorflowlite.so --fat_apk_cpu=arm64-v8a
# # For ARM 32 bit
# bazel build -c opt //tensorflow/lite:libtensorflowlite.so --fat_apk_cpu=arm-v7a
# Out:
# Extracting Bazel installation...
# Starting local Bazel server and connecting to it...
# WARNING: ignoring LD_PRELOAD in environment.
# INFO: Options provided by the client:
#   Inherited 'common' options: --isatty=1 --terminal_columns=0
# INFO: Reading rc options for 'build' from /content/tensorflow/.bazelrc:
#   Inherited 'common' options: --experimental_repo_remote_exec
# INFO: Reading rc options for 'build' from /content/tensorflow/.bazelrc:
#   'build' options: --define framework_shared_object=true --java_toolchain=@org_tensorflow//third_party/toolchains/java:tf_java_toolchain --host_java_toolchain=@org_tensorflow//third_party/toolchains/java:tf_java_toolchain --//tensorflow/core/kernels/mlir_generated:enable_gpu=false --define=use_fast_cpp_protos=true --define=allow_oversize_protos=true --spawn_strategy=standalone -c opt --announce_rc --define=grpc_no_ares=true --noincompatible_remove_legacy_whole_archive --noincompatible_prohibit_aapt1 --enable_platform_specific_config --config=short_logs --config=v2 --config=xla
# INFO: Found applicable config definition build:short_logs in file /content/tensorflow/.bazelrc: --output_filter=DONT_MATCH_ANYTHING
# INFO: Found applicable config definition build:v2 in file /content/tensorflow/.bazelrc: --define=tf_api_version=2 --action_env=TF2_BEHAVIOR=1
# INFO: Found applicable config definition build:xla in file /content/tensorflow/.bazelrc: --define=with_xla_support=true
# INFO: Found applicable config definition build:linux in file /content/tensorflow/.bazelrc: --copt=-w --host_copt=-w --define=PREFIX=/usr --define=LIBDIR=$(PREFIX)/lib --define=INCLUDEDIR=$(PREFIX)/include --define=PROTOBUF_INCLUDE_PATH=$(PREFIX)/include --cxxopt=-std=c++14 --host_cxxopt=-std=c++14 --config=dynamic_kernels
# INFO: Found applicable config definition build:dynamic_kernels in file /content/tensorflow/.bazelrc: --define=dynamic_loaded_kernels=true --copt=-DAUTOLOAD_DYNAMIC_KERNELS
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (2 packages loaded, 0\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (3 packages loaded, 1\
#  target configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (7 packages loaded, 6\
#  targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (8 packages loaded, 1\
# 1 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (11 packages loaded, \
# 11 targets configured)
#     currently loading: @bazel_tools//tools/jdk
#     Fetching @local_execution_config_python; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (11 packages loaded, \
# 11 targets configured)
#     currently loading: @bazel_tools//tools/jdk
#     Fetching @local_execution_config_python; fetching
#     Fetching @rules_java; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (12 packages loaded, \
# 11 targets configured)
#     Fetching @local_execution_config_python; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (12 packages loaded, \
# 11 targets configured)
#     Fetching @local_execution_config_python; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (12 packages loaded, \
# 11 targets configured)
#     Fetching @local_execution_config_python; fetching
#     Fetching @go_sdk; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (12 packages loaded, \
# 11 targets configured)
#     Fetching @local_execution_config_python; fetching
#     Fetching @go_sdk; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (12 packages loaded, \
# 11 targets configured)
#     Fetching @local_execution_config_python; fetching
#     Fetching @go_sdk; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (13 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 12,197,808B
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (13 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 18,620,288B
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (13 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 28,270,384B
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (13 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 35,438,336B
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (13 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 45,170,352B
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (13 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 49,626,768B
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 57,106,000B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 65,822,224B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 70,163,952B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 80,600,480B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...go1.12.5.linux-amd64.tar.gz; 92,781,888B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...o1.12.5.linux-amd64.tar.gz; 104,570,096B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching https://dl.google.com/...o1.12.5.linux-amd64.tar.gz; 112,745,648B
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching
#     Fetching ...docker; Cloning 251f6a68b439744094faff800cd029798edf9faa of ht\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
#     Fetching @go_sdk; fetching 4s
# DEBUG: Rule 'io_bazel_rules_docker' indicated that a canonical reproducible form can be obtained by modifying arguments shallow_since = "1556410077 -0400"
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
# DEBUG: Repository io_bazel_rules_docker instantiated at:
#   /content/tensorflow/WORKSPACE:23:14: in <toplevel>
#   /content/tensorflow/tensorflow/workspace0.bzl:105:34: in workspace
#   /root/.cache/bazel/_bazel_root/889612a75a81b3d8b4ed860522ba4e34/external/bazel_toolchains/repositories/repositories.bzl:37:23: in repositories
# Repository rule git_repository defined at:
#   /root/.cache/bazel/_bazel_root/889612a75a81b3d8b4ed860522ba4e34/external/bazel_tools/tools/build_defs/repo/git.bzl:199:33: in <toplevel>
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (14 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (15 packages loaded, \
# 11 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (16 packages loaded, \
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (16 packages loaded, \
# 19 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (19 packages loaded, \
# 111 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (20 packages loaded, \
# 122 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (21 packages loaded, \
# 122 targets configured)
#     currently loading: @bazel_tools//tools/def_parser
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (22 packages loaded, \
# 122 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (23 packages loaded, \
# 122 targets configured)
#     currently loading: tensorflow/lite/schema
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (25 packages loaded, \
# 134 targets configured)
#     currently loading: tensorflow/lite/schema
#     Fetching @flatbuffers; fetching
#     Fetching ...uffers; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/flatbuffers/temp4352079122624766907/v1.12.0.tar.\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (25 packages loaded, \
# 136 targets configured)
#     currently loading: tensorflow/lite/schema
#     Fetching @flatbuffers; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (26 packages loaded, \
# 146 targets configured)
#     currently loading: tensorflow/lite/schema
#     Fetching @flatbuffers; fetching
#     Fetching ...uffers; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/flatbuffers/temp16396666353175834051/v1.12.0.tar\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (26 packages loaded, \
# 151 targets configured)
#     currently loading: tensorflow/lite/schema
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (31 packages loaded, \
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (33 packages loaded, \
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (33 packages loaded, \
# 270 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (37 packages loaded, \
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (37 packages loaded, \
# 396 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (41 packages loaded, \
# 427 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (43 packages loaded, \
# 430 targets configured)
#     currently loading: tensorflow/core
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (45 packages loaded, \
# 430 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (46 packages loaded, \
# 554 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (50 packages loaded, \
# 554 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (52 packages loaded, \
# 569 targets configured)
#     currently loading: tensorflow/core/kernels
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (55 packages loaded, \
# 569 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (56 packages loaded, \
# 633 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (59 packages loaded, \
# 695 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (59 packages loaded, \
# 748 targets configured)
#     currently loading: tensorflow/core/kernels
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (59 packages loaded, \
# 748 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (61 packages loaded, \
# 748 targets configured)
#     currently loading: tensorflow/core/kernels
#     Fetching @cpuinfo; fetching
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (61 packages loaded, \
# 748 targets configured)
#     currently loading: tensorflow/core/kernels
#     Fetching @cpuinfo; fetching
#     Fetching ...puinfo; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/cpuinfo/temp1287567954468236735/6cecd15784fcb6c5\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (61 packages loaded, \
# 748 targets configured)
#     currently loading: tensorflow/core/kernels
#     Fetching @cpuinfo; fetching
#     Fetching ...puinfo; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/cpuinfo/temp5682166018695150284/6cecd15784fcb6c5\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (61 packages loaded, \
# 748 targets configured)
#     currently loading: tensorflow/core/kernels
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (62 packages loaded, \
# 778 targets configured)
#     currently loading: tensorflow/core/kernels
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (62 packages loaded, \
# 778 targets configured)
#     currently loading: tensorflow/core/kernels
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (62 packages loaded, \
# 778 targets configured)
#     currently loading: tensorflow/core/kernels
#     Fetching @clog; fetching
#     Fetching ...l/clog; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/clog/temp7008202265275995889/d5e37adf1406cf899d7\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (62 packages loaded, \
# 778 targets configured)
#     currently loading: tensorflow/core/kernels
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (63 packages loaded, \
# 923 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (64 packages loaded, \
# 1055 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (64 packages loaded, \
# 1058 targets configured)
#     Fetching @eigen_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/eigen_archive/temp1060626605253010601/eigen-f612\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (64 packages loaded, \
# 1116 targets configured)
#     currently loading: tensorflow/lite/tools/optimize/sparsity
#     Fetching @eigen_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/eigen_archive/temp1060626605253010601/eigen-f612\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (66 packages loaded, \
# 1242 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (66 packages loaded, \
# 1245 targets configured)
#     Fetching @eigen_archive; fetching
#     Fetching ...rchive; Extracting /root/.cache/bazel/_bazel_root/889612a75a81\
# b3d8b4ed860522ba4e34/external/eigen_archive/temp10781257972619666588/eigen-f61\
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (66 packages loaded, \
# 1245 targets configured)
# Analyzing: target //tensorflow/lite:libtensorflowlite.so (67 packages loaded, \
# INFO: Analyzed target //tensorflow/lite:libtensorflowlite.so (67 packages loaded, 1746 targets configured).
# INFO: Found 1 target...
# [50 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 0s local
# [50 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 1s local
# [50 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 2s local
# [50 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 3s local
# [51 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 3s local
# [51 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 3s local
# [51 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 4s local
# [51 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 5s local
# [51 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 6s local
# [51 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 7s local
# [52 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_kotlin.cpp [for host]; 8s local
# [53 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_lobster.cpp [for host]; 0s local
# [53 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_lobster.cpp [for host]; 1s local
# [53 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_lobster.cpp [for host]; 2s local
# [53 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_lobster.cpp [for host]; 3s local
# [53 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_lobster.cpp [for host]; 4s local
# [54 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_dart.cpp [for host]; 4s local
# [54 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_dart.cpp [for host]; 5s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 0s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 0s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 1s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 2s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 3s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 4s local
# [55 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 5s local
# [56 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 5s local
# [56 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 6s local
# [56 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_rust.cpp [for host]; 7s local
# [57 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_json_schema.cpp [for host]; 1s local
# [57 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_json_schema.cpp [for host]; 1s local
# [57 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_json_schema.cpp [for host]; 2s local
# [58 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp [for host]; 1s local
# [58 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp [for host]; 1s local
# [58 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp [for host]; 2s local
# [59 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 1s local
# [59 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 1s local
# [59 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 2s local
# [59 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 3s local
# [59 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 4s local
# [60 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 5s local
# [61 / 295] 2 actions running
#     Compiling flatbuffers/src/util.cpp [for host]; 0s local
# [61 / 295] 2 actions running
#     Compiling flatbuffers/src/util.cpp [for host]; 1s local
# [62 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/swift_generator.cc [for host]; 1s local
# [62 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/swift_generator.cc [for host]; 1s local
# [63 / 295] 2 actions, 1 running
#     Compiling flatbuffers/.../compiler/java_generator.cc [for host]; 1s local
# [63 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/java_generator.cc [for host]; 1s local
# [63 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/java_generator.cc [for host]; 2s local
# [63 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/java_generator.cc [for host]; 3s local
# [63 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/java_generator.cc [for host]; 4s local
# [64 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_php.cpp [for host]; 3s local
# [64 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_php.cpp [for host]; 4s local
# [65 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 0s local
# [65 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 1s local
# [65 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 2s local
# [65 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 3s local
# [65 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp [for host]; 4s local
# [66 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/reflection.cpp [for host]; 3s local
# [66 / 295] 2 actions running
#     Compiling flatbuffers/src/reflection.cpp [for host]; 4s local
# [67 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 0s local
# [67 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 0s local
# [67 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 1s local
# [67 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 2s local
# [68 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 2s local
# [68 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 3s local
# [69 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 4s local
# [69 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 4s local
# [69 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 5s local
# [69 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_python.cpp [for host]; 6s local
# [70 / 295] 2 actions, 1 running
#     Compiling flatbuffers/.../compiler/cpp_generator.cc [for host]; 2s local
# [70 / 295] 2 actions running
#     Compiling flatbuffers/.../compiler/cpp_generator.cc [for host]; 2s local
# [71 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 0s local
# [71 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 1s local
# [71 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 2s local
# [71 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 3s local
# [72 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 3s local
# [72 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 4s local
# [72 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 5s local
# [72 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 6s local
# [72 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 7s local
# [72 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 8s local
# [73 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 8s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 9s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 10s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 11s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 12s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 13s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 14s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 15s local
# [73 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp [for host]; 16s local
# [74 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_js_ts.cpp [for host]; 7s local
# [74 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_js_ts.cpp [for host]; 7s local
# [74 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_js_ts.cpp [for host]; 8s local
# [75 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 1s local
# [75 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 1s local
# [75 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 2s local
# [75 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 3s local
# [76 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 4s local
# [76 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 5s local
# [76 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 6s local
# [76 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 7s local
# [76 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_csharp.cpp [for host]; 8s local
# [77 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_java.cpp [for host]; 3s local
# [77 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_java.cpp [for host]; 4s local
# [78 / 295] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_go.cpp [for host]; 1s local
# [79 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_go.cpp [for host]; 1s local
# [79 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_go.cpp [for host]; 2s local
# [79 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_go.cpp [for host]; 3s local
# [79 / 295] 2 actions running
#     Compiling flatbuffers/src/idl_gen_go.cpp [for host]; 4s local
# [80 / 300] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 4s local
# [85 / 324] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 4s local
# [110 / 327] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 4s local
# [113 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 5s local
# [113 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 6s local
# [114 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 7s local
# [114 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 7s local
# [114 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 8s local
# [114 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 9s local
# [114 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 10s local
# [115 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 11s local
# [115 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_cpp.cpp [for host]; 11s local
# [116 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 0s local
# [116 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 0s local
# [117 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 0s local
# [117 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 1s local
# [118 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 1s local
# [118 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 1s local
# [119 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 1s local
# [119 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 1s local
# [120 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/internal/kernel_utils.cc; 2s local
# [121 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 0s local
# [122 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 0s local
# [122 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 0s local
# [122 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 1s local
# [122 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 2s local
# [123 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 3s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 3s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 4s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 5s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 6s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 7s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 8s local
# [124 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 9s local
# [125 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 10s local
# [125 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 10s local
# [126 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 10s local
# [126 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 11s local
# [127 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 11s local
# [127 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 11s local
# [128 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 12s local
# [129 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 12s local
# [130 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 12s local
# [131 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 13s local
# [132 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 13s local
# [132 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 13s local
# [132 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 14s local
# [133 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 15s local
# [133 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 15s local
# [133 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 16s local
# [134 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_parser.cpp; 16s local
# [134 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_parser.cpp; 16s local
# [135 / 329] 2 actions running
#     Compiling ruy/ruy/pack_avx2_fma.cc; 0s local
# [136 / 329] 2 actions running
#     Compiling ruy/ruy/kernel_arm32.cc; 0s local
# [137 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/context_get_ctx.cc; 0s local
# [138 / 329] 2 actions running
#     Compiling ruy/ruy/context_get_ctx.cc; 0s local
# [140 / 329] 2 actions running
#     Compiling ruy/ruy/context.cc; 0s local
# [140 / 329] 2 actions running
#     Compiling ruy/ruy/context.cc; 0s local
# [141 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_context.cc; 0s local
# [142 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_context.cc; 0s local
# [143 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/pack_avx.cc; 0s local
# [145 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/thread_pool.cc; 0s local
# [145 / 329] 2 actions running
#     Compiling ruy/ruy/thread_pool.cc; 0s local
# [146 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/thread_pool.cc; 0s local
# [150 / 329] 2 actions, 1 running
#     Compiling cpuinfo/src/x86/cache/init.c; 0s local
# [153 / 329] 2 actions, 1 running
#     Compiling cpuinfo/src/x86/cache/descriptor.c; 0s local
# [156 / 329] 2 actions running
#     Compiling ruy/ruy/kernel_avx512.cc; 0s local
# [157 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/internal/tensor_utils.cc; 0s local
# [158 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/tensor_utils.cc; 0s local
# [159 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/tensor_utils.cc; 1s local
# [160 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/internal/tensor_utils.cc; 1s local
# [161 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 0s local
# [161 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 0s local
# [162 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 1s local
# [163 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 1s local
# [164 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 2s local
# [164 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 2s local
# [164 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_text.cpp; 3s local
# [165 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/internal/spectrogram.cc; 2s local
# [166 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/internal/spectrogram.cc; 2s local
# [167 / 329] 2 actions running
#     Compiling .../kernels/internal/optimized/neon_tensor_utils.cc; 0s local
# [168 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 0s local
# [168 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 1s local
# [169 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 1s local
# [169 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 1s local
# [171 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 1s local
# [171 / 329] 2 actions running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 2s local
# [172 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/idl_gen_fbs.cpp; 2s local
# [173 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/kernel_avx2_fma.cc; 0s local
# [174 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/ctx.cc; 0s local
# [175 / 329] 2 actions running
#     Compiling ruy/ruy/ctx.cc; 0s local
# [176 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/ctx.cc; 0s local
# [178 / 329] 2 actions running
#     Compiling ruy/ruy/prepare_packed_matrices.cc; 0s local
# [179 / 329] 2 actions, 1 running
#     Compiling ruy/ruy/block_map.cc; 0s local
# [180 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_gemm_eigen.cc; 0s local
# [180 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_gemm_eigen.cc; 1s local
# [180 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_gemm_eigen.cc; 2s local
# [180 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_gemm_eigen.cc; 3s local
# [181 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/cpu_backend_gemm_eigen.cc; 4s local
# [181 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cpu_backend_gemm_eigen.cc; 4s local
# [182 / 329] 2 actions, 1 running
#     Compiling flatbuffers/src/util.cpp; 0s local
# [182 / 329] 2 actions running
#     Compiling flatbuffers/src/util.cpp; 0s local
# [183 / 329] 2 actions running
#     Compiling flatbuffers/src/util.cpp; 1s local
# [187 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/kernel_util.cc; 0s local
# [191 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/kernel_util.cc; 0s local
# [192 / 329] 2 actions running
#     Compiling tensorflow/lite/schema/schema_utils.cc; 0s local
# [192 / 329] 2 actions running
#     Compiling tensorflow/lite/schema/schema_utils.cc; 0s local
# [192 / 329] 2 actions running
#     Compiling tensorflow/lite/schema/schema_utils.cc; 1s local
# [193 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/util.cc; 1s local
# [193 / 329] 2 actions running
#     Compiling tensorflow/lite/util.cc; 1s local
# [194 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/core/api/op_resolver.cc; 0s local
# [194 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/op_resolver.cc; 1s local
# [195 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/core/api/op_resolver.cc; 2s local
# [196 / 329] 2 actions running
#     Compiling tensorflow/lite/mutable_op_resolver.cc; 0s local
# [196 / 329] 2 actions running
#     Compiling tensorflow/lite/mutable_op_resolver.cc; 1s local
# [196 / 329] 2 actions running
#     Compiling tensorflow/lite/mutable_op_resolver.cc; 2s local
# [197 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/eigen_support.cc; 2s local
# [197 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/eigen_support.cc; 2s local
# [197 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/eigen_support.cc; 3s local
# [199 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 1s local
# [199 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 1s local
# [200 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 2s local
# [200 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 2s local
# [200 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 3s local
# [201 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 3s local
# [201 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 3s local
# [201 / 329] 2 actions running
#     Compiling tensorflow/lite/core/api/flatbuffer_conversions.cc; 4s local
# [202 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/interpreter_builder.cc; 1s local
# [202 / 329] 2 actions running
#     Compiling tensorflow/lite/interpreter_builder.cc; 1s local
# [203 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/interpreter_builder.cc; 2s local
# [203 / 329] 2 actions running
#     Compiling tensorflow/lite/interpreter_builder.cc; 2s local
# [203 / 329] 2 actions running
#     Compiling tensorflow/lite/interpreter_builder.cc; 3s local
# [204 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/core/subgraph.cc; 1s local
# [204 / 329] 2 actions running
#     Compiling tensorflow/lite/core/subgraph.cc; 2s local
# [204 / 329] 2 actions running
#     Compiling tensorflow/lite/core/subgraph.cc; 3s local
# [205 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/optional_debug_tools.cc; 1s local
# [205 / 329] 2 actions running
#     Compiling tensorflow/lite/optional_debug_tools.cc; 2s local
# [206 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/topk_v2.cc; 0s local
# [206 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/topk_v2.cc; 1s local
# [207 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/topk_v2.cc; 1s local
# [207 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/topk_v2.cc; 1s local
# [208 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/elementwise.cc; 0s local
# [208 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/elementwise.cc; 1s local
# [208 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/elementwise.cc; 2s local
# [209 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/register.cc; 1s local
# [209 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/register.cc; 2s local
# [210 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/floor.cc; 0s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 1s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 2s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 3s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 4s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 5s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 6s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 7s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 8s local
# [210 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/floor.cc; 9s local
# [211 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/pooling.cc; 8s local
# [211 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/pooling.cc; 8s local
# [211 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/pooling.cc; 9s local
# [211 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/pooling.cc; 10s local
# [212 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/pooling.cc; 11s local
# [213 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 0s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 1s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 2s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 3s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 4s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 5s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 6s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 7s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 8s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 9s local
# [213 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 10s local
# [214 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 10s local
# [214 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_bilinear.cc; 11s local
# [215 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 0s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 0s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 1s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 2s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 3s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 4s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 5s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 6s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 7s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 8s local
# [215 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 9s local
# [216 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/space_to_batch_nd.cc; 10s local
# [217 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/add_n.cc; 0s local
# [217 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/add_n.cc; 0s local
# [217 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/add_n.cc; 1s local
# [218 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/comparisons.cc; 1s local
# [218 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/comparisons.cc; 2s local
# [218 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/comparisons.cc; 3s local
# [218 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/comparisons.cc; 4s local
# [218 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/comparisons.cc; 5s local
# [219 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/conv.cc; 3s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 4s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 5s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 6s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 7s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 8s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 9s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 10s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 11s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 12s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 13s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 14s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 15s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 15s local
# [219 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 16s local
# [220 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/conv.cc; 16s local
# [220 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 17s local
# [220 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 18s local
# [221 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/conv.cc; 18s local
# [221 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 19s local
# [222 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/conv.cc; 19s local
# [222 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 19s local
# [223 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/conv.cc; 20s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 20s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 21s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 22s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 23s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 24s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 25s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 26s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 27s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 28s local
# [223 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 29s local
# [224 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/conv.cc; 30s local
# [224 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 30s local
# [224 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 31s local
# [224 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 32s local
# [224 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 33s local
# [224 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 34s local
# [224 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/conv.cc; 35s local
# [225 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/add.cc; 6s local
# ...
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 0s local
# [274 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 1s local
# [275 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 2s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 2s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 3s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 4s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 5s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 6s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 7s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 8s local
# [275 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/scatter_nd.cc; 9s local
# [276 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 7s local
# [276 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 8s local
# [277 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 8s local
# [277 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 9s local
# [278 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 9s local
# [278 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 9s local
# [279 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 10s local
# [279 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 10s local
# [279 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 12s local
# [280 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 12s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 13s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 14s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 15s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 16s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 17s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 18s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 19s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 20s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 21s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 22s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 23s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 24s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 25s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 26s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 27s local
# [280 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/fully_connected.cc; 28s local
# [281 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/lstm.cc; 16s local
# [281 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/lstm.cc; 16s local
# [281 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/lstm.cc; 17s local
# [281 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/lstm.cc; 18s local
# [281 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/lstm.cc; 19s local
# [281 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/lstm.cc; 20s local
# [281 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/lstm.cc; 21s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 5s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 5s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 6s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 7s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 8s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 9s local
# [282 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/local_response_norm.cc; 10s local
# [283 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 5s local
# [284 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 6s local
# [284 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 6s local
# [284 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 7s local
# [284 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 8s local
# [284 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 9s local
# [285 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 9s local
# [285 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 10s local
# [285 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 11s local
# [286 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 11s local
# [286 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 12s local
# [287 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 12s local
# [287 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 12s local
# [287 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 13s local
# [287 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/cumsum.cc; 14s local
# [288 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 2s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 3s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 4s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 5s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 6s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 7s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 8s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 9s local
# [288 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/numeric_verify.cc; 10s local
# [289 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/matrix_diag.cc; 8s local
# [289 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_diag.cc; 8s local
# [289 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_diag.cc; 9s local
# [290 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 1s local
# [290 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 1s local
# [290 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 2s local
# [291 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 3s local
# [291 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 3s local
# [291 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 4s local
# [291 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 5s local
# [291 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 6s local
# [291 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 7s local
# [292 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 8s local
# [292 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 8s local
# [292 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/matrix_set_diag.cc; 9s local
# [293 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 1s local
# [293 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 2s local
# [294 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 2s local
# [294 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 2s local
# [295 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 3s local
# [295 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 3s local
# [296 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 3s local
# [297 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 3s local
# [297 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 4s local
# [298 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 4s local
# [298 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 4s local
# [299 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 5s local
# [300 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 5s local
# [301 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 6s local
# [301 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 6s local
# [301 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 7s local
# [301 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 8s local
# [301 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/mfcc.cc; 9s local
# [302 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 4s local
# [302 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 4s local
# [302 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 5s local
# [302 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 6s local
# [302 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 7s local
# [302 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 8s local
# [302 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/resize_nearest_neighbor.cc; 9s local
# [303 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 6s local
# [304 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 6s local
# [304 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 7s local
# [305 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 7s local
# [305 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 8s local
# [306 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 8s local
# [306 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 9s local
# [306 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/arg_min_max.cc; 10s local
# [307 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 2s local
# [307 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 3s local
# [308 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 3s local
# [309 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 3s local
# [310 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 4s local
# [310 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 4s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 4s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 4s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 5s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 6s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 7s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 8s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 9s local
# [311 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/detection_postprocess.cc; 10s local
# [312 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 6s local
# [312 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 7s local
# [313 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 7s local
# [313 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 8s local
# [314 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 8s local
# [314 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 9s local
# [315 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 10s local
# [315 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 10s local
# [316 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 10s local
# [317 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 11s local
# [317 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 12s local
# [317 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 13s local
# [317 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 14s local
# [317 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/transpose_conv.cc; 15s local
# [318 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 4s local
# [318 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 4s local
# [318 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 5s local
# [319 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 6s local
# [322 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/split_v.cc; 6s local
# [322 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 6s local
# [323 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/split_v.cc; 7s local
# [323 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 7s local
# [324 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/split_v.cc; 8s local
# [324 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 8s local
# [324 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 9s local
# [324 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/split_v.cc; 10s local
# [325 / 329] 2 actions, 1 running
#     Compiling tensorflow/lite/kernels/select.cc; 2s local
# [325 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/select.cc; 2s local
# [325 / 329] 2 actions running
#     Compiling tensorflow/lite/kernels/select.cc; 3s local
# Target //tensorflow/lite:libtensorflowlite.so up-to-date:
#   bazel-bin/tensorflow/lite/libtensorflowlite.so
# INFO: Elapsed time: 571.353s, Critical Path: 53.34s
# INFO: 329 processes: 84 internal, 245 local.
# INFO: Build completed successfully, 329 total actions

# %% [markdown]
# The shared library (`.so` file) would be located in `tensorflow/bazel-bin/tensorflow/lite/libtensorflowlite.so`.
